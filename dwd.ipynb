# %%
import os
import pandas as pd
file123=[]
for root, dirs, files in os.walk('./minimal/'):
    for file in files:    
        print (file), file123.append(file)
# Out:
# Transcription profiling by array of Arabidopsis Col-0, Fei-0, Bur-0, C24, Sha, Bay-0 and Bl-1 after treatment with indole-3-acetic acid.csv
# Transcription profiling of aerial parts of Arabidopsis wild type and arr10 arr12 double mutant seedlings treated with the cytokinin trans-zeatin.csv
# Transcription profiling by array of Arabidopsis Col-0, Fei-0, Bur-0, C24, Sha, Bay-0 and Bl-1 after treatment with indole-3-acetic acid-checkpoint.csv
# Transcription profiling of aerial parts of Arabidopsis wild type and arr10 arr12 double mutant seedlings treated with the cytokinin trans-zeatin-checkpoint.csv

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.cluster.hierarchy as sch
import glob 
from functools import reduce

# %%
file123[1]
# Out:
# 'Transcription profiling of aerial parts of Arabidopsis wild type and arr10 arr12 double mutant seedlings treated with the cytokinin trans-zeatin.csv'

# %%
file_dc = {}
for x in file123:
    file_dc={x:[]}
    print (file_dc)
# Out:
# {'Transcription profiling by array of Arabidopsis Col-0, Fei-0, Bur-0, C24, Sha, Bay-0 and Bl-1 after treatment with indole-3-acetic acid.csv': []}
# {'Transcription profiling of aerial parts of Arabidopsis wild type and arr10 arr12 double mutant seedlings treated with the cytokinin trans-zeatin.csv': []}
# {'Transcription profiling by array of Arabidopsis Col-0, Fei-0, Bur-0, C24, Sha, Bay-0 and Bl-1 after treatment with indole-3-acetic acid-checkpoint.csv': []}
# {'Transcription profiling of aerial parts of Arabidopsis wild type and arr10 arr12 double mutant seedlings treated with the cytokinin trans-zeatin-checkpoint.csv': []}

# %%
all_dfs = files_dict #add DFs 
for k, v in all_dfs.items():
    exec("all_dfs['%s'] = %s" % (k, k))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7d80c640a3d5> in <module>()
# ----> 1 all_dfs = files_dict #add DFs
#       2 for k, v in all_dfs.items():
#       3     exec("all_dfs['%s'] = %s" % (k, k))
#
# NameError: name 'files_dict' is not defined

# %%
dongu= os.path.expanduser('/root/Downloads/jupyter/minimal//') 
# create a dict of strings with pd name as key and filename as value 
files_dict = {} 
files = os.listdir(dongu)
dong=[]
for f in files: 
    if f.endswith('.csv'): 
        key = f[:-len('.csv')] 
        key = key.replace(" ", "_") 
        key = key.replace("-", "_") 
        key = key.replace(",","_")
        files_dict[key] = f
        for k, v in files_dict.items():
            exec("%s = pd.read_csv( '/root/Downloads/jupyter/minimal/%s')" % (k, v))
            dong.append(k)

# %%
dong1=eval(dong[0])

# %%
dong1
# Out:
#       #Transcription profiling by array of Arabidopsis Col-0, Fei-0, Bur-0, C24, Sha, Bay-0 and Bl-1 after treatment with indole-3-acetic acid  \
# 0                                                    #as
# 1                                                   #abs
# 2                                                    #bs
# 3                                         #organism part
# 4                                              #compound
# 5                                                Gene ID
# 6                                              AT1G01010
# 7                                              AT1G01030
# 8                                              AT1G01040
# 9                                              AT1G01050
# 10                                             AT1G01060
# 11                                             AT1G01070
# 12                                             AT1G01080
# 13                                             AT1G01090
# ...

# %%
#파일갯수대로 카운트 3개변 0,1,2,리스트 만드는거
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-755c35019fa0> in <module>()
# ----> 1 length=len(files_dict).int
#
# AttributeError: 'int' object has no attribute 'int'

# %%
abc=list(files_dict)

# %%
abc
# Out:
# ['Transcription_profiling_by_array_of_Arabidopsis_Col_0___Fei_0___Bur_0___C24___Sha___Bay_0_and_Bl_1_after_treatment_with_indole_3_acetic_acid',
#  'Transcription_profiling_of_aerial_parts_of_Arabidopsis_wild_type_and_arr10_arr12_double_mutant_seedlings_treated_with_the_cytokinin_trans_zeatin']

# %%
dongu= os.path.expanduser('/root/Downloads/jupyter/minimal//') 
# create a dict of strings with pd name as key and filename as value 
files_dict = {} 
files = os.listdir(dongu)
woo={}
for f in files: 
    if f.endswith('.csv'): 
        key = f[:-len('.csv')] 
        key = key.replace(" ", "_") 
        key = key.replace("-", "_") 
        key = key.replace(",","__")
        files_dict[key] = f
        for x, e in files_dict.items():
            
            exec("df_list = pd.read_csv( '/root/Downloads/jupyter/minimal/%s',comment='#',skiprows=1)" % ( e))

# %%
df_list[]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-b2e52ef7a20d> in <module>()
# ----> 1 df_list[1]
#
# ...

# %%
eval(k)
# Out:
#       #Transcription profiling by array of Arabidopsis Col-0, Fei-0, Bur-0, C24, Sha, Bay-0 and Bl-1 after treatment with indole-3-acetic acid  \
# 0                                                    #as
# 1                                                   #abs
# 2                                                    #bs
# 3                                         #organism part
# 4                                              #compound
# 5                                                Gene ID
# 6                                              AT1G01010
# 7                                              AT1G01030
# 8                                              AT1G01040
# 9                                              AT1G01050
# 10                                             AT1G01060
# 11                                             AT1G01070
# 12                                             AT1G01080
# 13                                             AT1G01090
# ...

# %%
eval(x)
# Out:
#          Gene ID     Gene Name DesignElementAccession  \
# 0      AT1G01010        NAC001              261585_at
# 1      AT1G01030          NGA3              261568_at
# 2      AT1G01040          DCL1              261584_at
# 3      AT1G01050          PPA1              261579_at
# 4      AT1G01060           LHY              261569_at
# 5      AT1G01070           NaN              261576_at
# 6      AT1G01080           NaN              261577_at
# 7      AT1G01090  PDH-E1 ALPHA              261583_at
# 8      AT1G01100         RPP1A              261578_at
# 9      AT1G01110         IQD18              261580_at
# 10     AT1G01120          KCS1              261570_at
# 11     AT1G01130           NaN              261575_at
# 12     AT1G01140         CIPK9              261581_at
# 13     AT1G01150           NaN              261571_at
# 14     AT1G01160          GIF2              261582_at
# 15     AT1G01170           NaN              261572_at
# ...

# %%
#다른형태의 df를 만들어 dong과 woo에 저장함

# %%
woo=eval(woo)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-20e3f1df80d6> in <module>()
# ----> 1 woo=eval(woo)
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
df_mat = reduce(lambda a,b : pd.merge(a,b,on="Gene ID",how='outer'),woo)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-1077bccf6026> in <module>()
# ----> 1 df_mat = reduce(lambda a,b : pd.merge(a,b,on="Gene ID",how='outer'),woo)
#
# <ipython-input-19-1077bccf6026> in <lambda>(a, b)
# ----> 1 df_mat = reduce(lambda a,b : pd.merge(a,b,on="Gene ID",how='outer'),woo)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      55                          right_index=right_index, sort=sort, suffixes=suffixes,
#      56                          copy=copy, indicator=indicator,
# ---> 57                          validate=validate)
#      58     return op.get_result()
#      59
#
# ...
