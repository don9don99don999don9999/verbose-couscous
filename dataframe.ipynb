# %%
import os
import pandas as pd
for root, dirs, files in os.walk('./data'):
    for file in files:    
        print (file)
# Out:
# GSM1603940_1_Col_ctrl_old_htseq-counts.tsv
# GSM1603941_15_Col_ctrl_old_htseq-counts.tsv
# GSM1603942_29_Col_ctrl_old_htseq-counts.tsv
# GSM1603943_8_Col_ozone_old_htseq-counts.tsv
# GSM1603944_22_Col_ozone_old_htseq-counts.tsv
# GSM1603945_36_Col_ozone_old_htseq-counts.tsv
# GSM1603946_7_Triple_ctrl_htseq-counts.tsv
# GSM1603947_21_Triple_ctrl_htseq-counts.tsv
# GSM1603948_35_Triple_ctrl_htseq-counts.tsv
# GSM1603949_14_Triple_ozone_htseq-counts.tsv
# GSM1603950_28_Triple_ozone_htseq-counts.tsv
# GSM1603951_42_Triple_ozone_htseq-counts.tsv
# GSM1603952_7_col_ctrl_htseq-counts.tsv
# GSM1603953_15_col_ctrl_htseq-counts.tsv
# GSM1603954_23_col_ctrl_htseq-counts.tsv
# GSM1603955_11_col_oz_htseq-counts.tsv
# GSM1603956_19_col_oz_htseq-counts.tsv
# GSM1603957_27_col_oz_htseq-counts.tsv
# GSM1603958_8_tga_ctrl_htseq-counts.tsv
# GSM1603959_16_tga_ctrl_htseq-counts.tsv
# GSM1603960_24_tga_ctrl_htseq-counts.tsv
# GSM1603961_12_tga_oz_htseq-counts.tsv
# GSM1603962_20_tga_oz_htseq-counts.tsv
# GSM1603963_28_tga_oz_htseq-counts.tsv

# %%
import glob
glob.glob('./data/*.tsv')
# Out:
# ['./data/GSM1603940_1_Col_ctrl_old_htseq-counts.tsv',
#  './data/GSM1603941_15_Col_ctrl_old_htseq-counts.tsv',
#  './data/GSM1603942_29_Col_ctrl_old_htseq-counts.tsv',
#  './data/GSM1603943_8_Col_ozone_old_htseq-counts.tsv',
#  './data/GSM1603944_22_Col_ozone_old_htseq-counts.tsv',
#  './data/GSM1603945_36_Col_ozone_old_htseq-counts.tsv',
#  './data/GSM1603946_7_Triple_ctrl_htseq-counts.tsv',
#  './data/GSM1603947_21_Triple_ctrl_htseq-counts.tsv',
#  './data/GSM1603948_35_Triple_ctrl_htseq-counts.tsv',
#  './data/GSM1603949_14_Triple_ozone_htseq-counts.tsv',
#  './data/GSM1603950_28_Triple_ozone_htseq-counts.tsv',
#  './data/GSM1603951_42_Triple_ozone_htseq-counts.tsv',
#  './data/GSM1603952_7_col_ctrl_htseq-counts.tsv',
#  './data/GSM1603953_15_col_ctrl_htseq-counts.tsv',
#  './data/GSM1603954_23_col_ctrl_htseq-counts.tsv',
#  './data/GSM1603955_11_col_oz_htseq-counts.tsv',
#  './data/GSM1603956_19_col_oz_htseq-counts.tsv',
#  './data/GSM1603957_27_col_oz_htseq-counts.tsv',
#  './data/GSM1603958_8_tga_ctrl_htseq-counts.tsv',
#  './data/GSM1603959_16_tga_ctrl_htseq-counts.tsv',
#  './data/GSM1603960_24_tga_ctrl_htseq-counts.tsv',
#  './data/GSM1603961_12_tga_oz_htseq-counts.tsv',
#  './data/GSM1603962_20_tga_oz_htseq-counts.tsv',
#  './data/GSM1603963_28_tga_oz_htseq-counts.tsv']

# %%
os.chdir('/root/Downloads/jupyter/data')
results = pd.DataFrame([])
for counter, file in enumerate(glob.glob("GSM*")):
    namedf=pd.read_csv(file, skiprows=0 ,sep='\t' )
    results=results.append(namedf)
    
results.to_csv('./data.csv ')

# %%
namedf
# Out:
#               id chr   start     end   len strand  count
# 0      AT1G01010   1    3630    5899  2269      +    376
# 1      AT1G01020   1    5927    8737  2810      -    287
# 2      AT1G01030   1   11648   13714  2066      -    119
# 3      AT1G01040   1   23145   31227  8082      +    739
# 4      AT1G01046   1   28499   28706   207      +      8
# 5      AT1G01050   1   31169   33153  1984      -    851
# 6      AT1G01060   1   33378   37871  4493      -    586
# 7      AT1G01070   1   38751   40944  2193      -     97
# 8      AT1G01073   1   44676   44787   111      +      0
# 9      AT1G01080   1   45295   47019  1724      -    939
# 10     AT1G01090   1   47484   49286  1802      -   2460
# 11     AT1G01100   1   50074   51199  1125      -   3537
# 12     AT1G01110   1   52238   54692  2454      +     66
# 13     AT1G01115   1   56623   56740   117      +      0
# 14     AT1G01120   1   57268   59167  1899      -    629
# 15     AT1G01130   1   61904   63811  1907      -     24
# 16     AT1G01140   1   64165   67625  3460      -    984
# 17     AT1G01150   1   70114   72138  2024      -      3
# 18     AT1G01160   1   72338   74096  1758      +    453
# 19     AT1G01170   1   73930   74737   807      -    496
# 20     AT1G01180   1   75582   76758  1176      +    307
# 21     AT1G01183   1   78931   79032   101      -      0
# 22     AT1G01190   1   83044   84864  1820      -    178
# 23     AT1G01200   1   86514   88213  1699      -     20
# 24     AT1G01210   1   88897   89745   848      +    116
# 25     AT1G01220   1   91375   95651  4276      +    722
# 26     AT1G01225   1   95986   97407  1421      +     30
# 27     AT1G01230   1   97455   99240  1785      +    810
# 28     AT1G01240   1   99893  101834  1941      +    265
# 29     AT1G01250   1  104490  105330   840      -      7
# ...          ...  ..     ...     ...   ...    ...    ...
# 33572  ATMG01130  Mt  289196  289517   321      -      3
# 33573  ATMG01140  Mt  292972  293431   459      -      0
# 33574  ATMG01150  Mt  293975  294296   321      -      0
# 33575  ATMG01160  Mt  296687  296784    97      -      0
# 33576  ATMG01170  Mt  296819  298204  1385      -      7
# 33577  ATMG01180  Mt  300965  301301   336      -      4
# 33578  ATMG01190  Mt  302165  303689  1524      -      0
# 33579  ATMG01200  Mt  303835  304720   885      -      3
# 33580  ATMG01210  Mt  304778  305084   306      -      0
# 33581  ATMG01220  Mt  305220  305562   342      -      3
# 33582  ATMG01230  Mt  308931  309369   438      +      0
# 33583  ATMG01240  Mt  309337  309640   303      -      0
# 33584  ATMG01250  Mt  310513  310882   369      +      0
# 33585  ATMG01260  Mt  312544  313162   618      -      0
# 33586  ATMG01270  Mt  314626  315073   447      +      0
# 33587  ATMG01275  Mt  318003  318390   387      -      0
# 33588  ATMG01280  Mt  318587  319463   876      -      0
# 33589  ATMG01290  Mt  324258  324594   336      +      0
# 33590  ATMG01300  Mt  325299  325710   411      +      0
# 33591  ATMG01310  Mt  326098  326509   411      +      0
# 33592  ATMG01320  Mt  327889  333105  5216      -      1
# 33593  ATMG01330  Mt  329081  329465   384      -      0
# 33594  ATMG01340  Mt  337668  337741    73      +      0
# 33595  ATMG01350  Mt  346756  347194   438      +      1
# 33596  ATMG01360  Mt  349829  351413  1584      -     12
# 33597  ATMG01370  Mt  360716  361052   336      -     23
# 33598  ATMG01380  Mt  361061  361179   118      -     10
# 33599  ATMG01390  Mt  361349  363284  1935      -    509
# 33600  ATMG01400  Mt  363724  364042   318      +      0
# 33601  ATMG01410  Mt  366085  366700   615      -      6
#
# [33602 rows x 7 columns]

# %%
results
# Out:
#               id chr   start     end   len strand  count
# 0      AT1G01010   1    3630    5899  2269      +     67
# 1      AT1G01020   1    5927    8737  2810      -    299
# 2      AT1G01030   1   11648   13714  2066      -    107
# 3      AT1G01040   1   23145   31227  8082      +   1213
# 4      AT1G01046   1   28499   28706   207      +     13
# 5      AT1G01050   1   31169   33153  1984      -   1363
# 6      AT1G01060   1   33378   37871  4493      -   1233
# 7      AT1G01070   1   38751   40944  2193      -    165
# 8      AT1G01073   1   44676   44787   111      +      0
# 9      AT1G01080   1   45295   47019  1724      -   2157
# 10     AT1G01090   1   47484   49286  1802      -   3149
# 11     AT1G01100   1   50074   51199  1125      -   2866
# 12     AT1G01110   1   52238   54692  2454      +     56
# 13     AT1G01115   1   56623   56740   117      +      0
# 14     AT1G01120   1   57268   59167  1899      -   1350
# 15     AT1G01130   1   61904   63811  1907      -     20
# 16     AT1G01140   1   64165   67625  3460      -   1650
# 17     AT1G01150   1   70114   72138  2024      -      0
# 18     AT1G01160   1   72338   74096  1758      +    369
# 19     AT1G01170   1   73930   74737   807      -    935
# 20     AT1G01180   1   75582   76758  1176      +    179
# 21     AT1G01183   1   78931   79032   101      -      1
# 22     AT1G01190   1   83044   84864  1820      -    145
# 23     AT1G01200   1   86514   88213  1699      -     32
# 24     AT1G01210   1   88897   89745   848      +    113
# 25     AT1G01220   1   91375   95651  4276      +    589
# 26     AT1G01225   1   95986   97407  1421      +     78
# 27     AT1G01230   1   97455   99240  1785      +    394
# 28     AT1G01240   1   99893  101834  1941      +    565
# 29     AT1G01250   1  104490  105330   840      -     68
# ...          ...  ..     ...     ...   ...    ...    ...
# 33572  ATMG01130  Mt  289196  289517   321      -      3
# 33573  ATMG01140  Mt  292972  293431   459      -      0
# 33574  ATMG01150  Mt  293975  294296   321      -      0
# 33575  ATMG01160  Mt  296687  296784    97      -      0
# 33576  ATMG01170  Mt  296819  298204  1385      -      7
# 33577  ATMG01180  Mt  300965  301301   336      -      4
# 33578  ATMG01190  Mt  302165  303689  1524      -      0
# 33579  ATMG01200  Mt  303835  304720   885      -      3
# 33580  ATMG01210  Mt  304778  305084   306      -      0
# 33581  ATMG01220  Mt  305220  305562   342      -      3
# 33582  ATMG01230  Mt  308931  309369   438      +      0
# 33583  ATMG01240  Mt  309337  309640   303      -      0
# 33584  ATMG01250  Mt  310513  310882   369      +      0
# 33585  ATMG01260  Mt  312544  313162   618      -      0
# 33586  ATMG01270  Mt  314626  315073   447      +      0
# 33587  ATMG01275  Mt  318003  318390   387      -      0
# 33588  ATMG01280  Mt  318587  319463   876      -      0
# 33589  ATMG01290  Mt  324258  324594   336      +      0
# 33590  ATMG01300  Mt  325299  325710   411      +      0
# 33591  ATMG01310  Mt  326098  326509   411      +      0
# 33592  ATMG01320  Mt  327889  333105  5216      -      1
# 33593  ATMG01330  Mt  329081  329465   384      -      0
# 33594  ATMG01340  Mt  337668  337741    73      +      0
# 33595  ATMG01350  Mt  346756  347194   438      +      1
# 33596  ATMG01360  Mt  349829  351413  1584      -     12
# 33597  ATMG01370  Mt  360716  361052   336      -     23
# 33598  ATMG01380  Mt  361061  361179   118      -     10
# 33599  ATMG01390  Mt  361349  363284  1935      -    509
# 33600  ATMG01400  Mt  363724  364042   318      +      0
# 33601  ATMG01410  Mt  366085  366700   615      -      6
#
# [806448 rows x 7 columns]

# %%
df = pd.read_csv('./data.csv',sep='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-98-f02839cf9a3e> in <module>()
# ----> 1 df = pd.read_csv('./data.csv',sep='\t')
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'./data.csv' does not exist

# %%
# Out:
# ['./data/GSM1603940_1_Col_ctrl_old_htseq-counts.tsv',
#  './data/GSM1603941_15_Col_ctrl_old_htseq-counts.tsv',
#  './data/GSM1603942_29_Col_ctrl_old_htseq-counts.tsv',
#  './data/GSM1603943_8_Col_ozone_old_htseq-counts.tsv',
#  './data/GSM1603944_22_Col_ozone_old_htseq-counts.tsv',
#  './data/GSM1603945_36_Col_ozone_old_htseq-counts.tsv',
#  './data/GSM1603946_7_Triple_ctrl_htseq-counts.tsv',
#  './data/GSM1603947_21_Triple_ctrl_htseq-counts.tsv',
#  './data/GSM1603948_35_Triple_ctrl_htseq-counts.tsv',
#  './data/GSM1603949_14_Triple_ozone_htseq-counts.tsv',
#  './data/GSM1603950_28_Triple_ozone_htseq-counts.tsv',
#  './data/GSM1603951_42_Triple_ozone_htseq-counts.tsv',
#  './data/GSM1603952_7_col_ctrl_htseq-counts.tsv',
#  './data/GSM1603953_15_col_ctrl_htseq-counts.tsv',
#  './data/GSM1603954_23_col_ctrl_htseq-counts.tsv',
#  './data/GSM1603955_11_col_oz_htseq-counts.tsv',
#  './data/GSM1603956_19_col_oz_htseq-counts.tsv',
#  './data/GSM1603957_27_col_oz_htseq-counts.tsv',
#  './data/GSM1603958_8_tga_ctrl_htseq-counts.tsv',
#  './data/GSM1603959_16_tga_ctrl_htseq-counts.tsv',
#  './data/GSM1603960_24_tga_ctrl_htseq-counts.tsv',
#  './data/GSM1603961_12_tga_oz_htseq-counts.tsv',
#  './data/GSM1603962_20_tga_oz_htseq-counts.tsv',
#  './data/GSM1603963_28_tga_oz_htseq-counts.tsv']
