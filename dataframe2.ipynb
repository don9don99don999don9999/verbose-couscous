# %%
import pandas as pd
import glob
import os
path = '/root/Downloads/jupyter/data/' 
all_files = glob.glob(os.path.join(path,"GSM*"))
merged = pd.concat((pd.read_csv(f,sep='\t') for f in all_files),axis=1)

# %%
all_files
# Out:
# ['/root/Downloads/jupyter/data/GSM1603940_1_Col_ctrl_old_htseq-counts.tsv',
#  '/root/Downloads/jupyter/data/GSM1603941_15_Col_ctrl_old_htseq-counts.tsv',
#  '/root/Downloads/jupyter/data/GSM1603942_29_Col_ctrl_old_htseq-counts.tsv',
#  '/root/Downloads/jupyter/data/GSM1603943_8_Col_ozone_old_htseq-counts.tsv',
#  '/root/Downloads/jupyter/data/GSM1603944_22_Col_ozone_old_htseq-counts.tsv',
#  '/root/Downloads/jupyter/data/GSM1603945_36_Col_ozone_old_htseq-counts.tsv',
#  '/root/Downloads/jupyter/data/GSM1603946_7_Triple_ctrl_htseq-counts.tsv',
#  '/root/Downloads/jupyter/data/GSM1603947_21_Triple_ctrl_htseq-counts.tsv',
#  '/root/Downloads/jupyter/data/GSM1603948_35_Triple_ctrl_htseq-counts.tsv',
#  '/root/Downloads/jupyter/data/GSM1603949_14_Triple_ozone_htseq-counts.tsv',
#  '/root/Downloads/jupyter/data/GSM1603950_28_Triple_ozone_htseq-counts.tsv',
#  '/root/Downloads/jupyter/data/GSM1603951_42_Triple_ozone_htseq-counts.tsv',
# ...

# %%
merged
# Out:
#               id chr   start     end   len  strand count         id chr  \
# 0      AT1G01010   1    3630    5899  2269       +    67  AT1G01010   1
# 1      AT1G01020   1    5927    8737  2810       -   299  AT1G01020   1
# 2      AT1G01030   1   11648   13714  2066       -   107  AT1G01030   1
# 3      AT1G01040   1   23145   31227  8082       +  1213  AT1G01040   1
# 4      AT1G01046   1   28499   28706   207       +    13  AT1G01046   1
# 5      AT1G01050   1   31169   33153  1984       -  1363  AT1G01050   1
# 6      AT1G01060   1   33378   37871  4493       -  1233  AT1G01060   1
# 7      AT1G01070   1   38751   40944  2193       -   165  AT1G01070   1
# 8      AT1G01073   1   44676   44787   111       +     0  AT1G01073   1
# 9      AT1G01080   1   45295   47019  1724       -  2157  AT1G01080   1
# 10     AT1G01090   1   47484   49286  1802       -  3149  AT1G01090   1
# 11     AT1G01100   1   50074   51199  1125       -  2866  AT1G01100   1
# ...
