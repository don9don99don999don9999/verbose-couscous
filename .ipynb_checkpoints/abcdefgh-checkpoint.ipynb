# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.cluster.hierarchy as sch
import glob 
from functools import reduce

# %%
file_tpm_list = glob.glob('./minimal/*.csv')

#file_tpm_list
#비교를위해 df_list 와  df_list1을 만듬. df_list3은 what_x,what_y를 뽑기위해.
df_list = [pd.read_csv(x) for x in file_tpm_list]
df_list3= [pd.read_csv(x)[['#what','what']] for x in file_tpm_list]
df_list1 = [pd.read_csv(x,comment='#',skiprows=1) for x in file_tpm_list]
df_mat = reduce(lambda a,b : pd.merge(a,b,on="#what",how='outer'),df_list)
df_mat1= reduce(lambda a,b : pd.merge(a,b,on=["Gene ID",'Gene Name','DesignElementAccession'],how='outer'),df_list1)
df_mat3 = reduce(lambda a,b : pd.merge(a,b,on="#what",how='outer'),df_list3)

# %%
df_list[0].at[5,'Unnamed: 3'] == df_list1[0].columns[3]
# Out:
# True

# %%
# Out:
# 'Quint_2-71_Col-0-3h_Rep2_ATH1'

# %%
df_list[0].columns[2:]
# Out:
# Index(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')

# %%
file_tpm_list
# Out:
# ['./minimal/Transcription profiling by array of Arabidopsis Col-0, Fei-0, Bur-0, C24, Sha, Bay-0 and Bl-1 after treatment with indole-3-acetic acid (1).csv',
#  './minimal/Transcription profiling of aerial parts of Arabidopsis wild type and arr10 arr12 double mutant seedlings treated with the cytokinin trans-zeatin (1).csv']

# %%
df=pd.read_csv('./minimal/Transcription profiling by array of Arabidopsis Col-0, Fei-0, Bur-0, C24, Sha, Bay-0 and Bl-1 after treatment with indole-3-acetic acid (1).csv',comment='#',skiprows=0)

# %%
df2=df[['Gene ID','Gene Name','DesignElementAccession']] # df2에 붙여넣기위해서 geneid... etc로만된 df만듬

# %%
df_mat3.columns
# Out:
# Index(['#what', 'what_x', 'what_y'], dtype='object')

# %%
df_mat = reduce(lambda a,b : pd.merge(a,b,on="#what",how='outer'),df_list)
df_mat1= reduce(lambda a,b : pd.merge(a,b,on=["Gene ID",'Gene Name','DesignElementAccession'],how='outer'),df_list1)

# %%
df_mat
# Out:
#                     #what          what_x            Unnamed: 2_x  \
# 0                     #as            molm                     NaN
# 1                    #abs        alliumsm                     NaN
# 2                     #bs   gunggmhajianm                     NaN
# 3          #organism part  whole organism                     NaN
# 4               #compound             NaN                     NaN
# 5                 Gene ID       Gene Name  DesignElementAccession
# 6               AT1G01010          NAC001               261585_at
# 7               AT1G01030            NGA3               261568_at
# 8               AT1G01040            DCL1               261584_at
# 9               AT1G01050            PPA1               261579_at
# 10              AT1G01060             LHY               261569_at
# 11              AT1G01070             NaN               261576_at
# 12              AT1G01080             NaN               261577_at
# ...

# %%
df_mat.columns
# Out:
# Index(['#what', 'what_x', 'Unnamed: 2_x', 'Unnamed: 3_x', 'Unnamed: 4_x',
#        'Unnamed: 5_x', 'Unnamed: 6_x', 'Unnamed: 7_x', 'Unnamed: 8_x',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'what_y', 'Unnamed: 2_y', 'Unnamed: 3_y',
#        'Unnamed: 4_y', 'Unnamed: 5_y', 'Unnamed: 6_y', 'Unnamed: 7_y',
#        'Unnamed: 8_y'],
#       dtype='object')

# %%
df_mat1#genename과
# Out:
#          Gene ID     Gene Name DesignElementAccession  \
# 0      AT1G01010        NAC001              261585_at
# 1      AT1G01030          NGA3              261568_at
# 2      AT1G01040          DCL1              261584_at
# 3      AT1G01050          PPA1              261579_at
# 4      AT1G01060           LHY              261569_at
# 5      AT1G01070           NaN              261576_at
# 6      AT1G01080           NaN              261577_at
# 7      AT1G01090  PDH-E1 ALPHA              261583_at
# 8      AT1G01100         RPP1A              261578_at
# 9      AT1G01110         IQD18              261580_at
# 10     AT1G01120          KCS1              261570_at
# 11     AT1G01130           NaN              261575_at
# 12     AT1G01140         CIPK9              261581_at
# 13     AT1G01150           NaN              261571_at
# 14     AT1G01160          GIF2              261582_at
# 15     AT1G01170           NaN              261572_at
# ...

# %%
col={} 
for x in df_mat.columns: 
    key=df_mat.at[5,x]
    values=df_mat.at[4,x]
    col[key]=values
    print(key,values)
# Out:
# Gene ID #compound
# Gene Name nan
# DesignElementAccession nan
# Quint_2-71_Col-0-3h_Rep2_ATH1 indole-3-acetic acid
# Quint_2-67_Col-0-1h_Rep1_ATH1 indole-3-acetic acid
# Quint_2-62_Col-0-0h_Rep2_ATH1 nan
# Quint_2-61_Col-0-0h_Rep1_ATH1 nan
# Quint_2-66_Col-0-30min_Rep3_ATH1 indole-3-acetic acid
# Quint_2-72_Col-0-3h_Rep3_ATH1 indole-3-acetic acid
# Quint_2-70_Col-0-3h_Rep1_ATH1 nan
# Quint_2-65_Col-0-30min_Rep2_ATH1 nan
# Quint_2-69_Col-0-1h_Rep3_ATH1 nan
# Quint_2-64_Col-0-30min_Rep1_ATH1 nan
# Quint_2-63_Col-0-0h_Rep3_ATH1 nan
# Quint_2-68_Col-0-1h_Rep2_ATH1 nan
# Gene Name nan
# DesignElementAccession nan
# NASCArrays:Tab2MAGE:E-NASC-75.20.Hybridization DMSO
# NASCArrays:Tab2MAGE:E-NASC-75.17.Hybridization DMSO
# NASCArrays:Tab2MAGE:E-NASC-75.32.Hybridization t-zeatin
# NASCArrays:Tab2MAGE:E-NASC-75.38.Hybridization t-zeatin
# NASCArrays:Tab2MAGE:E-NASC-75.13.Hybridization DMSO
# NASCArrays:Tab2MAGE:E-NASC-75.35.Hybridization t-zeatin

# %%
p=df_mat.at[0,'what_y'] #df_mat['what']으로된 df를 만들었따. 
#거기서 원래친구들을 구분시켜서 p를 어떻게 집어넣나? 에러를 만나면  다음 컬럼 넣아라. 하면됨. if df_mat['what_x']있을때 what_x ㄱㄱ
c=df.at[1,'..1']

for k in col:
    #exec("df1['%s;%s;%s;%s'] = df1['%s']"% (k,p,c,col[k],k))
    df1['%s;%s;%s;%s'%(k,p,c,col[k])] = df1['%s'%k]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7e03ee3762d1> in <module>()
#       1 p=df_mat.at[0,'what_y'] #df_mat['what']으로된 df를 만들었따.
#       2 #거기서 원래친구들을 구분시켜서 p를 어떻게 집어넣나? 에러를 만나면  다음 컬럼 넣아라. 하면됨. if df_mat['what_x']있을때 what_x ㄱㄱ
# ----> 3 c=df.at[1,'..1']
#       4
#       5 for k in col:
#
# NameError: name 'df' is not defined

# %%
p=df_mat.at[0,'what_y']

# %%
from pandas import Series, DataFrame

# %%
[df_list[x].at[0,'what'] for x in [0,1]]
# Out:
# ['molm', '2 (week)']

# %%
ab=[x.at[0,'what'] for x in df_list]

# %%
# Out:
# ['molm',
#  '2 (week)',
#  'molm',
#  '2 (week)',
#  'molm',
#  '2 (week)',
#  'molm',
#  '2 (week)',
#  'molm',
#  '2 (week)',
#  'molm',
#  '2 (week)',
#  'molm',
#  '2 (week)']

# %%
df_list[1].at[0,'what']
# Out:
# '2 (week)'

# %%
for k in col:
    df2['%s;%s'%(k,col[k])] = df_mat1['%s'%k] 

    #데이터 프레임 만드는방법 이용.

# %%
df2
# Out:
#          Gene ID     Gene Name DesignElementAccession  \
# 0      AT1G01010        NAC001              261585_at
# 1      AT1G01030          NGA3              261568_at
# 2      AT1G01040          DCL1              261584_at
# 3      AT1G01050          PPA1              261579_at
# 4      AT1G01060           LHY              261569_at
# 5      AT1G01070           NaN              261576_at
# 6      AT1G01080           NaN              261577_at
# 7      AT1G01090  PDH-E1 ALPHA              261583_at
# 8      AT1G01100         RPP1A              261578_at
# 9      AT1G01110         IQD18              261580_at
# 10     AT1G01120          KCS1              261570_at
# 11     AT1G01130           NaN              261575_at
# 12     AT1G01140         CIPK9              261581_at
# 13     AT1G01150           NaN              261571_at
# 14     AT1G01160          GIF2              261582_at
# 15     AT1G01170           NaN              261572_at
# ...

# %% [markdown]
# ---

# %% [markdown]
# glob를 이용해서 dir하위 file을 땡겨옴.
# excel파일에서의 # 공통이 있어야함. 엑셀 1,1이 같은것이 좋음.
# #처리한 list와 #처리하지 않은 df리스트를 가져옴
# #col이라는 사전을 만들어서 key 5번줄 value(treat) 4번줄 로 하게함.
# #df2에 df2['%s;%s'%(k,col[k])] = df_mat1['%s'%k]이런식으로 추가할수있음. 중간중간 유전자이름,디자인어쩌고 삭제방법, 추가될 요소들에서 [df_list[x].at[0,'what'] for x in [0,1]],,,
# #ab=[x.at[0,'what'] for x in df_list]으로 요소를 땅겨올수 잇엇다. '요소들'의 집합을 구함.
# #[a,b,c,d.....] 가 0,1,2,3 순서임. 각각으로 보내고싶음.
# #x=(0~file갯수-1) if 써서 df_list[x].at[5,'Unnamed: 3'] == df_list1[x].columns[3] 맞으면,
# #ab[x]를return
